# %%
import pandas as pd
import numpy as np

# %%
both = pd.read_csv("../data/both.tsv", sep="\t")

# %%
both
# Out:
#                         host  host_taxid   host_rank host_group  \
# 0                 sus scrofa      9823.0     species    mammals
# 1           macropus eugenii      9315.0     species    mammals
# 2      oryctolagus cuniculus      9986.0     species    mammals
# 3                 sus scrofa      9823.0     species    mammals
# 4     canis lupus familiaris      9615.0  subspecies    mammals
# 5           macropus eugenii      9315.0     species    mammals
# 6     canis lupus familiaris      9615.0  subspecies    mammals
# 7               capra hircus      9925.0     species    mammals
# 8                 bos taurus      9913.0     species    mammals
# 9               capra hircus      9925.0     species    mammals
# 10    canis lupus familiaris      9615.0  subspecies    mammals
# 11                bos taurus      9913.0     species    mammals
# 12          macropus eugenii      9315.0     species    mammals
# 13          macropus eugenii      9315.0     species    mammals
# ...
