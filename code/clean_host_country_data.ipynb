# %%
import pandas as pd
import numpy as np
from collections import Counter
import string
import Bio
import Bio.Entrez as Entrez
import json
import time
import xmltodict
import copy

# %%
def trimPunc(astring):
    letters = set(list(string.ascii_lowercase))
    letters.add(" ")
    letters.add("[")
    letters.add("]")
    letters.add("-")
    L = list(astring)
    L2 = []
    for l in L:
        if l in letters:
            L2.append(l)
        else:
            break
    clean = "".join(L2).replace("[", "").replace("]", "")
    clean = clean.strip()
    clean = clean.replace(" type", "")
    clean = clean.replace(" ", "_")
    return (clean)

# %%
data = pd.read_csv("../data/both.tsv", sep="\t")
data['host'] = data['host'].str.replace(" ", "_")
data['host'] = data['host'].str.split("_").str.get(0) + "_" + data['host'].str.split("_").str.get(1)

# %%
data['path'] = data['path'].astype(str)

# %%
data['path_clean'] = data['path'].apply(lambda x: trimPunc(x))

# %%
data = data[data['path_clean'].str.find('uncultured') == -1]

# %%
pdict = dict()
for p in set(data['path_clean']):
    p2 = p
    if 'virus' in p and 'rotavirus' not in p:
        p = p.split("virus")[0] + "virus"
    if p.endswith("_str"):
        p = "_".join(p.split("_")[:-1])
    p = p.replace("_subsp", "")
    if p.endswith("_phe"):
        p = p.replace("_phe", "")
    p = p.replace("-", "_")
    if p == 'visna':
        p = 'visna_virus'
    p = p.replace('eastern_equine', 'equine')
    if p.endswith("_pig"):
        p = p.replace("_pig", "")
    if 'rotavirus' in p and not p.endswith('rotavirus_a'):
        p = 'rotavirus_a'
    p = p.replace(" ", "_")
    p = p.replace("rabies_virus", "rabies_lyssavirus")
    if 'sfpork' not in p and 'sfbeef' not in p:
        pdict[p2] = p

# %%
data = data[data['path_clean'].isin(pdict)]
data['path_clean'] = [pdict[p] for p in data['path_clean']]
data['microbe_name'] = data['path_clean']

# %%
data['country'] = data['country'].str.replace("central african republic", "central african rep.")
data['country'] = data['country'].str.replace("czech republic", "czechia")
data['country'] = data['country'].str.replace("falkland islands", "argentina")
data['country'] = data['country'].str.replace("hong kong", "china")
data['country'] = data['country'].str.replace("ivory coast", "côte d'ivoire")
data['country'] = data['country'].str.replace("republic of the congo", "congo")
data['country'] = data['country'].str.replace("united states", "united states of america")
data = data[np.invert(data['country'].isnull())]

# %%
data = data[data['path_type'].isin(['bacteria', 'viruses'])]

# %%
hosts = set(data['host'])
good_hosts = set()
for host in hosts:
    paths = set(data['path_clean'][data['host'] == host])
    if len(paths) >= 5:
        good_hosts.add(host)

# %%
data = data[data['host'].isin(good_hosts)]

# %%
data = data.drop_duplicates()

# %%
sppnames = {'cow':'bos_taurus',
             'dog': 'canis_lupus',
             'goat': 'capra_hircus',
             'horse': 'equus_caballus',
             'cat':'felis_catus',
             'rabbit': 'oryctolagus_cuniculus',
             'sheep': 'ovis_aries',
             'pig': 'sus_scrofa'}

# %%
sppnames2 = {'bos_taurus': 'cow',
             'canis_lupus': 'dog',
             'capra_hircus': 'goat',
             'equus_caballus': 'horse',
             'felis_catus': 'cat',
             'oryctolagus_cuniculus': 'rabbit',
             'ovis_aries': 'sheep',
             'sus_scrofa': 'pig'}

# %%
data.index = range(len(data))

# %%
data['host_name'] = [sppnames2[s] for s in data['host']]

# %%
data['host_scientific_name'] = data['host']

# %%
data['number_of_samples'] = data['count']

# %%
data['microbe_type'] = data['path_type']

# %%
data = data[['host_name', 'host_scientific_name', 'microbe_name', 'microbe_type', 'country', 'number_of_samples']]

# %%
d2 = data.groupby(['host_name', 'microbe_name', 'country'])
nsamples = d2['number_of_samples'].apply(sum).values
d2 = d2.first()
d3 = d2[d2.columns]
d3.index = range(len(d3))
d3['host_name'] = [d[0] for d in d2.index]
d3['microbe_name'] = [d[1] for d in d2.index]
d3['country'] = [d[2] for d in d2.index]
d3['number_of_samples'] = nsamples
data = copy.copy(d3)
data = data[['host_name', 'host_scientific_name', 'microbe_name', 'microbe_type', 'country', 'number_of_samples']]

# %%
d = ['sheep', 'ovis_aries', 'visna_virus', 'virus', 'china', 78]
d2 = ['horse', 'equus_caballus', 'borna_disease_virus', 'viruses', 'united states of america', '150']
d3 = ['pig', 'sus_scrofa', 'brucella_suis', 'bacteria', 'india', '120']

# %%
nrows = len(data)

# %%
data.loc[nrows+1] = d
data.loc[nrows+2] = d2
data.loc[nrows+3] = d3

# %%
data = data.sort_values(['microbe_name', 'country', 'host_name'])

# %%
txids = dict()
for m in set(data['microbe_name']):
    print (m)
    m2 = m.replace("_", " ")
    D = None
    while D is None:
        try:
            D = Entrez.esearch(db='taxonomy', term=m2, retmode='json').read()
        except HTTPError:
            time.sleep(20)
    I = json.loads(D)['esearchresult']['idlist']
    if len(I) == 1:
        txids[m] = I[0]
    else:
        print ("x", m)
# Out:
# equine_papillomavirus
# /home/katy/miniconda3/lib/python3.6/site-packages/Bio/Entrez/__init__.py:580: UserWarning:
# Email address is not specified.
#
# To make use of NCBI's E-utilities, NCBI requires you to specify your
# email address with each request.  As an example, if your email address
# is A.N.Other@example.com, you can specify it as follows:
#    from Bio import Entrez
#    Entrez.email = 'A.N.Other@example.com'
# In case of excessive usage of the E-utilities, NCBI will attempt to contact
# a user at the email address provided before blocking access to the
# E-utilities.
#   E-utilities.""", UserWarning)
# encephalomyocarditis_virus
# campylobacter_coli
# mycoplasma_hyopneumoniae
# ovine_lentivirus
# bartonella_henselae
# cowpox_virus
# actinobacillus_porcitonsillarum
# porcine_picobirnavirus
# staphylococcus_epidermidis
# border_disease_virus
# bovine_rotavirus_a
# vaccinia_virus
# orf_virus
# chlamydia_abortus
# escherichia_coli
# caprine_herpesvirus
# x caprine_herpesvirus
# candidatus_mycoplasma_haemobos
# bovine_ephemeral_fever_virus
# porcine_circovirus
# burkholderia_mallei_gb
# x burkholderia_mallei_gb
# anaplasma_marginale
# feline_coronavirus
# swine_hepatitis_e_virus
# torque_teno_virus
# lactococcus_lactis
# borna_disease_virus
# equine_encephalitis_virus
# x equine_encephalitis_virus
# sapelovirus
# brucella_canis
# porcine_reproductive_and_respiratory_syndrome_virus
# classical_swine_fever_virus
# equid_herpesvirus
# x equid_herpesvirus
# brachyspira_canis
# equine_rotavirus_a
# mycoplasma_haemofelis
# escherichia_albertii
# hepatitis_e_virus
# porcine_parvovirus
# norwalk_like_virus
# suid_herpesvirus
# x suid_herpesvirus
# influenza_a_virus
# arcobacter_trophiarum
# feline_panleukopenia_virus
# hendra_virus
# campylobacter_jejuni
# chlamydia_pneumoniae
# ehrlichia_chaffeensis
# clostridium_botulinum
# porcine_teschovirus
# salmonella_enterica
# japanese_encephalitis_virus
# leptonema_illini_dsm
# x leptonema_illini_dsm
# west_nile_virus
# nicoletella_semolina
# bacillus_anthracis
# mycobacterium_avium
# small_ruminant_lentivirus
# bovine_viral_diarrhea_virus
# feline_immunodeficiency_virus
# moraxella_bovis
# brucella_abortus
# brucella_melitensis
# brachyspira_hyodysenteriae
# tt_virus
# haemophilus_parasuis
# porphyromonas_levii
# campylobacter_fetus
# bergeyella_zoohelcum
# peaton_virus
# streptococcus_dysgalactiae
# porcine_hokovirus
# porcine_kobuvirus
# actinobacillus_pleuropneumoniae
# brucella_ovis
# pseudocowpox_virus
# candidatus_mycoplasma_haemovis
# neorickettsia_risticii
# bovine_enteric_calicivirus
# yersinia_pseudotuberculosis
# staphylococcus_rostri
# porcine_rotavirus_a
# streptococcus_canis
# lawsonia_intracellularis
# rabbit_calicivirus
# caprine_arthritis_encephalitis_virus
# canine_coronavirus
# campylobacter_lanienae
# rotavirus_a
# brachyspira_pilosicoli
# feline_leukemia_virus
# bartonella_vinsonii
# streptococcus_suis
# peste_des_petits_ruminants_virus
# enterovirus
# prevotella_ruminicola
# rift_valley_fever_virus
# enterococcus_faecalis
# bluetongue_virus
# bartonella_chomelii
# cantagalo_virus
# bovine_foamy_virus
# bovine_leukemia_virus
# clostridium_perfringens
# african_horse_sickness_virus
# ehrlichia_canis
# bovine_papillomavirus
# mycoplasma_suis
# foot_and_mouth_disease_virus
# brazilian_caprine_lentivirus
# staphylococcus_pseudintermedius
# caprine_lentivirus
# aerococcus_viridans
# torque_teno_sus_virus
# bovine_herpesvirus
# x bovine_herpesvirus
# canine_distemper_virus
# equine_infectious_anemia_virus
# feline_calicivirus
# rabies_lyssavirus
# bovine_coronavirus
# betacoronavirus
# brucella_suis
# epizootic_hemorrhagic_disease_virus
# african_swine_fever_virus
# ovine_progressive_pneumonia_virus
# myxoma_virus
# ovine_herpesvirus
# x ovine_herpesvirus
# kobuvirus
# canine_parvovirus
# mammalian_orthoreovirus
# kimberley_virus
# aino_virus
# anaplasma_phagocytophilum
# streptococcus_pyogenes
# staphylococcus_aureus
# moraxella_bovoculi
# visna_virus
# rabbit_hemorrhagic_disease_virus
# porcine_epidemic_diarrhea_virus

# %%
data = data[data['microbe_name'].isin(txids)]

# %%
data['microbe_id'] = [txids[i] for i in data['microbe_name']]

# %%
fdict = dict()
for nam, t in txids.items():
    x = Entrez.efetch(db='taxonomy', id=t, rettype='xml', retmode='xml').read()
    x2 = xmltodict.parse(x)['TaxaSet']['Taxon']['LineageEx']['Taxon']
    for d in x2:
        if d['Rank'] == 'family':
            fdict[nam] = d['ScientificName']
# Out:
# /home/katy/miniconda3/lib/python3.6/site-packages/Bio/Entrez/__init__.py:580: UserWarning:
# Email address is not specified.
#
# To make use of NCBI's E-utilities, NCBI requires you to specify your
# email address with each request.  As an example, if your email address
# is A.N.Other@example.com, you can specify it as follows:
#    from Bio import Entrez
#    Entrez.email = 'A.N.Other@example.com'
# In case of excessive usage of the E-utilities, NCBI will attempt to contact
# a user at the email address provided before blocking access to the
# E-utilities.
#   E-utilities.""", UserWarning)

# %%
data['microbe_family'] = [fdict[i] for i in data['microbe_name']]

# %%
data = data[['host_name', 'host_scientific_name', 'microbe_name', 'microbe_id', 'microbe_family', 'microbe_type', 'country', 'number_of_samples']]

# %%
data['number_of_samples'] = data['number_of_samples'].astype(int)

# %%
data.to_csv("clean_data_geo_host.tsv", sep="\t", index=None)

# %%
data[data['microbe_name'] == 'rabies_lyssavirus']
# Out:
#     host_name host_scientific_name       microbe_name microbe_id  \
# 182       dog          canis_lupus  rabies_lyssavirus      11292
# 119       cow           bos_taurus  rabies_lyssavirus      11292
# 183       dog          canis_lupus  rabies_lyssavirus      11292
# 120       cow           bos_taurus  rabies_lyssavirus      11292
# 121       cow           bos_taurus  rabies_lyssavirus      11292
# 184       dog          canis_lupus  rabies_lyssavirus      11292
# 228      goat         capra_hircus  rabies_lyssavirus      11292
# 18        cat          felis_catus  rabies_lyssavirus      11292
# 122       cow           bos_taurus  rabies_lyssavirus      11292
# 185       dog          canis_lupus  rabies_lyssavirus      11292
# 268     horse       equus_caballus  rabies_lyssavirus      11292
# 186       dog          canis_lupus  rabies_lyssavirus      11292
# 187       dog          canis_lupus  rabies_lyssavirus      11292
# 188       dog          canis_lupus  rabies_lyssavirus      11292
# 189       dog          canis_lupus  rabies_lyssavirus      11292
# 123       cow           bos_taurus  rabies_lyssavirus      11292
# 190       dog          canis_lupus  rabies_lyssavirus      11292
# 19        cat          felis_catus  rabies_lyssavirus      11292
# 124       cow           bos_taurus  rabies_lyssavirus      11292
# 191       dog          canis_lupus  rabies_lyssavirus      11292
# 20        cat          felis_catus  rabies_lyssavirus      11292
# 125       cow           bos_taurus  rabies_lyssavirus      11292
# 192       dog          canis_lupus  rabies_lyssavirus      11292
# 193       dog          canis_lupus  rabies_lyssavirus      11292
# 194       dog          canis_lupus  rabies_lyssavirus      11292
# 126       cow           bos_taurus  rabies_lyssavirus      11292
# 195       dog          canis_lupus  rabies_lyssavirus      11292
# 229      goat         capra_hircus  rabies_lyssavirus      11292
# 127       cow           bos_taurus  rabies_lyssavirus      11292
# 196       dog          canis_lupus  rabies_lyssavirus      11292
# 128       cow           bos_taurus  rabies_lyssavirus      11292
# 197       dog          canis_lupus  rabies_lyssavirus      11292
# 129       cow           bos_taurus  rabies_lyssavirus      11292
# 198       dog          canis_lupus  rabies_lyssavirus      11292
# 199       dog          canis_lupus  rabies_lyssavirus      11292
# 21        cat          felis_catus  rabies_lyssavirus      11292
# 130       cow           bos_taurus  rabies_lyssavirus      11292
# 200       dog          canis_lupus  rabies_lyssavirus      11292
# 201       dog          canis_lupus  rabies_lyssavirus      11292
# 22        cat          felis_catus  rabies_lyssavirus      11292
# 202       dog          canis_lupus  rabies_lyssavirus      11292
# 131       cow           bos_taurus  rabies_lyssavirus      11292
# 203       dog          canis_lupus  rabies_lyssavirus      11292
# 132       cow           bos_taurus  rabies_lyssavirus      11292
# 204       dog          canis_lupus  rabies_lyssavirus      11292
# 205       dog          canis_lupus  rabies_lyssavirus      11292
# 206       dog          canis_lupus  rabies_lyssavirus      11292
# 133       cow           bos_taurus  rabies_lyssavirus      11292
# 207       dog          canis_lupus  rabies_lyssavirus      11292
# 230      goat         capra_hircus  rabies_lyssavirus      11292
# 208       dog          canis_lupus  rabies_lyssavirus      11292
# 23        cat          felis_catus  rabies_lyssavirus      11292
# 209       dog          canis_lupus  rabies_lyssavirus      11292
# 210       dog          canis_lupus  rabies_lyssavirus      11292
# 24        cat          felis_catus  rabies_lyssavirus      11292
# 211       dog          canis_lupus  rabies_lyssavirus      11292
# 212       dog          canis_lupus  rabies_lyssavirus      11292
# 213       dog          canis_lupus  rabies_lyssavirus      11292
#
#     microbe_family microbe_type                   country  number_of_samples
# 182  Rhabdoviridae      viruses               afghanistan                  6
# 119  Rhabdoviridae      viruses                 argentina                 14
# 183  Rhabdoviridae      viruses                 argentina                 23
# 120  Rhabdoviridae      viruses                bangladesh                  8
# 121  Rhabdoviridae      viruses                  botswana                  7
# 184  Rhabdoviridae      viruses                  botswana                  6
# 228  Rhabdoviridae      viruses                  botswana                  6
# 18   Rhabdoviridae      viruses                    brazil                 14
# 122  Rhabdoviridae      viruses                    brazil                330
# 185  Rhabdoviridae      viruses                    brazil                 34
# 268  Rhabdoviridae      viruses                    brazil                 39
# 186  Rhabdoviridae      viruses              burkina faso                 35
# 187  Rhabdoviridae      viruses                  cambodia                 12
# 188  Rhabdoviridae      viruses      central african rep.                  9
# 189  Rhabdoviridae      viruses                      chad                  9
# 123  Rhabdoviridae      viruses                     china                  7
# 190  Rhabdoviridae      viruses                     china                491
# 19   Rhabdoviridae      viruses                  colombia                 12
# 124  Rhabdoviridae      viruses                  colombia                 22
# 191  Rhabdoviridae      viruses                  colombia                 50
# 20   Rhabdoviridae      viruses                      cuba                 17
# 125  Rhabdoviridae      viruses                      cuba                 10
# 192  Rhabdoviridae      viruses                      cuba                 34
# 193  Rhabdoviridae      viruses             côte d'ivoire                 11
# 194  Rhabdoviridae      viruses                     ghana                 55
# 126  Rhabdoviridae      viruses                     india                 10
# 195  Rhabdoviridae      viruses                     india                 73
# 229  Rhabdoviridae      viruses                     india                  6
# 127  Rhabdoviridae      viruses                    israel                 10
# 196  Rhabdoviridae      viruses                    israel                 26
# 128  Rhabdoviridae      viruses                    mexico                 42
# 197  Rhabdoviridae      viruses                    mexico                  7
# 129  Rhabdoviridae      viruses                  mongolia                  7
# 198  Rhabdoviridae      viruses                   nigeria                206
# 199  Rhabdoviridae      viruses               philippines                  6
# 21   Rhabdoviridae      viruses                    poland                  7
# 130  Rhabdoviridae      viruses                    poland                  6
# 200  Rhabdoviridae      viruses                    poland                  6
# 201  Rhabdoviridae      viruses               puerto rico                  7
# 22   Rhabdoviridae      viruses                   romania                  7
# 202  Rhabdoviridae      viruses                    russia                  6
# 131  Rhabdoviridae      viruses              south africa                 10
# 203  Rhabdoviridae      viruses              south africa                194
# 132  Rhabdoviridae      viruses               south korea                 17
# 204  Rhabdoviridae      viruses               south korea                 10
# 205  Rhabdoviridae      viruses                     spain                  6
# 206  Rhabdoviridae      viruses                 sri lanka                  9
# 133  Rhabdoviridae      viruses                     sudan                  7
# 207  Rhabdoviridae      viruses                     sudan                 13
# 230  Rhabdoviridae      viruses                     sudan                  8
# 208  Rhabdoviridae      viruses                  tanzania                 25
# 23   Rhabdoviridae      viruses                  thailand                 12
# 209  Rhabdoviridae      viruses                  thailand                301
# 210  Rhabdoviridae      viruses                    turkey                 19
# 24   Rhabdoviridae      viruses                   ukraine                  7
# 211  Rhabdoviridae      viruses                   ukraine                 10
# 212  Rhabdoviridae      viruses  united states of america                 61
# 213  Rhabdoviridae      viruses                    zambia                 57
