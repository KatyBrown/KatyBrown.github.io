# %% [markdown]
# ## CAT
#
#
# [feline_leukemia_virus](feline_leukemia_virus_cat.tsv)
#
# [mycoplasma_haemofelis](mycoplasma_haemofelis_cat.tsv)
#
# [bartonella_henselae](bartonella_henselae_cat.tsv)
#
# [borna_disease_virus](borna_disease_virus_cat.tsv)
#
# [equine_infectious_anemia_virus](equine_infectious_anemia_virus_cat.tsv)
#
# [neorickettsia_risticii](neorickettsia_risticii_cat.tsv)
#
# [bartonella_vinsonii](bartonella_vinsonii_cat.tsv)
#
# [canine_parvovirus](canine_parvovirus_cat.tsv)
#
# [rabies_lyssavirus](rabies_lyssavirus_cat.tsv)
#
# [brucella_abortus](brucella_abortus_cat.tsv)
#
# [bovine_leukemia_virus](bovine_leukemia_virus_cat.tsv)
#
# [foot_and_mouth_disease_virus](foot_and_mouth_disease_virus_cat.tsv)
#
# [anaplasma_phagocytophilum](anaplasma_phagocytophilum_cat.tsv)
#
# [escherichia_coli](escherichia_coli_cat.tsv)
#
# [visna_virus](visna_virus_cat.tsv)
#
# [classical_swine_fever_virus](classical_swine_fever_virus_cat.tsv)
#
# [hepatitis_e_virus](hepatitis_e_virus_cat.tsv)
#
# [brucella_suis](brucella_suis_cat.tsv)
#
# [influenza_a_virus](influenza_a_virus_cat.tsv)
#
# [torque_teno_sus_virus](torque_teno_sus_virus_cat.tsv)
#
#
#
#
# ## HORSE
#
#
# [feline_leukemia_virus](feline_leukemia_virus_horse.tsv)
#
# [mycoplasma_haemofelis](mycoplasma_haemofelis_horse.tsv)
#
# [bartonella_henselae](bartonella_henselae_horse.tsv)
#
# [borna_disease_virus](borna_disease_virus_horse.tsv)
#
# [equine_infectious_anemia_virus](equine_infectious_anemia_virus_horse.tsv)
#
# [neorickettsia_risticii](neorickettsia_risticii_horse.tsv)
#
# [bartonella_vinsonii](bartonella_vinsonii_horse.tsv)
#
# [canine_parvovirus](canine_parvovirus_horse.tsv)
#
# [rabies_lyssavirus](rabies_lyssavirus_horse.tsv)
#
# [brucella_abortus](brucella_abortus_horse.tsv)
#
# [bovine_leukemia_virus](bovine_leukemia_virus_horse.tsv)
#
# [foot_and_mouth_disease_virus](foot_and_mouth_disease_virus_horse.tsv)
#
# [anaplasma_phagocytophilum](anaplasma_phagocytophilum_horse.tsv)
#
# [escherichia_coli](escherichia_coli_horse.tsv)
#
# [visna_virus](visna_virus_horse.tsv)
#
# [classical_swine_fever_virus](classical_swine_fever_virus_horse.tsv)
#
# [hepatitis_e_virus](hepatitis_e_virus_horse.tsv)
#
# [brucella_suis](brucella_suis_horse.tsv)
#
# [influenza_a_virus](influenza_a_virus_horse.tsv)
#
# [torque_teno_sus_virus](torque_teno_sus_virus_horse.tsv)
#
#
#
#
# ## DOG
#
#
# [feline_leukemia_virus](feline_leukemia_virus_dog.tsv)
#
# [mycoplasma_haemofelis](mycoplasma_haemofelis_dog.tsv)
#
# [bartonella_henselae](bartonella_henselae_dog.tsv)
#
# [borna_disease_virus](borna_disease_virus_dog.tsv)
#
# [equine_infectious_anemia_virus](equine_infectious_anemia_virus_dog.tsv)
#
# [neorickettsia_risticii](neorickettsia_risticii_dog.tsv)
#
# [bartonella_vinsonii](bartonella_vinsonii_dog.tsv)
#
# [canine_parvovirus](canine_parvovirus_dog.tsv)
#
# [rabies_lyssavirus](rabies_lyssavirus_dog.tsv)
#
# [brucella_abortus](brucella_abortus_dog.tsv)
#
# [bovine_leukemia_virus](bovine_leukemia_virus_dog.tsv)
#
# [foot_and_mouth_disease_virus](foot_and_mouth_disease_virus_dog.tsv)
#
# [anaplasma_phagocytophilum](anaplasma_phagocytophilum_dog.tsv)
#
# [escherichia_coli](escherichia_coli_dog.tsv)
#
# [visna_virus](visna_virus_dog.tsv)
#
# [classical_swine_fever_virus](classical_swine_fever_virus_dog.tsv)
#
# [hepatitis_e_virus](hepatitis_e_virus_dog.tsv)
#
# [brucella_suis](brucella_suis_dog.tsv)
#
# [influenza_a_virus](influenza_a_virus_dog.tsv)
#
# [torque_teno_sus_virus](torque_teno_sus_virus_dog.tsv)
#
#
#
#
# ## COW
#
#
# [feline_leukemia_virus](feline_leukemia_virus_cow.tsv)
#
# [mycoplasma_haemofelis](mycoplasma_haemofelis_cow.tsv)
#
# [bartonella_henselae](bartonella_henselae_cow.tsv)
#
# [borna_disease_virus](borna_disease_virus_cow.tsv)
#
# [equine_infectious_anemia_virus](equine_infectious_anemia_virus_cow.tsv)
#
# [neorickettsia_risticii](neorickettsia_risticii_cow.tsv)
#
# [bartonella_vinsonii](bartonella_vinsonii_cow.tsv)
#
# [canine_parvovirus](canine_parvovirus_cow.tsv)
#
# [rabies_lyssavirus](rabies_lyssavirus_cow.tsv)
#
# [brucella_abortus](brucella_abortus_cow.tsv)
#
# [bovine_leukemia_virus](bovine_leukemia_virus_cow.tsv)
#
# [foot_and_mouth_disease_virus](foot_and_mouth_disease_virus_cow.tsv)
#
# [anaplasma_phagocytophilum](anaplasma_phagocytophilum_cow.tsv)
#
# [escherichia_coli](escherichia_coli_cow.tsv)
#
# [visna_virus](visna_virus_cow.tsv)
#
# [classical_swine_fever_virus](classical_swine_fever_virus_cow.tsv)
#
# [hepatitis_e_virus](hepatitis_e_virus_cow.tsv)
#
# [brucella_suis](brucella_suis_cow.tsv)
#
# [influenza_a_virus](influenza_a_virus_cow.tsv)
#
# [torque_teno_sus_virus](torque_teno_sus_virus_cow.tsv)
#
#
#
#
# ## SHEEP
#
#
# [feline_leukemia_virus](feline_leukemia_virus_sheep.tsv)
#
# [mycoplasma_haemofelis](mycoplasma_haemofelis_sheep.tsv)
#
# [bartonella_henselae](bartonella_henselae_sheep.tsv)
#
# [borna_disease_virus](borna_disease_virus_sheep.tsv)
#
# [equine_infectious_anemia_virus](equine_infectious_anemia_virus_sheep.tsv)
#
# [neorickettsia_risticii](neorickettsia_risticii_sheep.tsv)
#
# [bartonella_vinsonii](bartonella_vinsonii_sheep.tsv)
#
# [canine_parvovirus](canine_parvovirus_sheep.tsv)
#
# [rabies_lyssavirus](rabies_lyssavirus_sheep.tsv)
#
# [brucella_abortus](brucella_abortus_sheep.tsv)
#
# [bovine_leukemia_virus](bovine_leukemia_virus_sheep.tsv)
#
# [foot_and_mouth_disease_virus](foot_and_mouth_disease_virus_sheep.tsv)
#
# [anaplasma_phagocytophilum](anaplasma_phagocytophilum_sheep.tsv)
#
# [escherichia_coli](escherichia_coli_sheep.tsv)
#
# [visna_virus](visna_virus_sheep.tsv)
#
# [classical_swine_fever_virus](classical_swine_fever_virus_sheep.tsv)
#
# [hepatitis_e_virus](hepatitis_e_virus_sheep.tsv)
#
# [brucella_suis](brucella_suis_sheep.tsv)
#
# [influenza_a_virus](influenza_a_virus_sheep.tsv)
#
# [torque_teno_sus_virus](torque_teno_sus_virus_sheep.tsv)
#
#
#
#
# ## PIG
#
#
# [feline_leukemia_virus](feline_leukemia_virus_pig.tsv)
#
# [mycoplasma_haemofelis](mycoplasma_haemofelis_pig.tsv)
#
# [bartonella_henselae](bartonella_henselae_pig.tsv)
#
# [borna_disease_virus](borna_disease_virus_pig.tsv)
#
# [equine_infectious_anemia_virus](equine_infectious_anemia_virus_pig.tsv)
#
# [neorickettsia_risticii](neorickettsia_risticii_pig.tsv)
#
# [bartonella_vinsonii](bartonella_vinsonii_pig.tsv)
#
# [canine_parvovirus](canine_parvovirus_pig.tsv)
#
# [rabies_lyssavirus](rabies_lyssavirus_pig.tsv)
#
# [brucella_abortus](brucella_abortus_pig.tsv)
#
# [bovine_leukemia_virus](bovine_leukemia_virus_pig.tsv)
#
# [foot_and_mouth_disease_virus](foot_and_mouth_disease_virus_pig.tsv)
#
# [anaplasma_phagocytophilum](anaplasma_phagocytophilum_pig.tsv)
#
# [escherichia_coli](escherichia_coli_pig.tsv)
#
# [visna_virus](visna_virus_pig.tsv)
#
# [classical_swine_fever_virus](classical_swine_fever_virus_pig.tsv)
#
# [hepatitis_e_virus](hepatitis_e_virus_pig.tsv)
#
# [brucella_suis](brucella_suis_pig.tsv)
#
# [influenza_a_virus](influenza_a_virus_pig.tsv)
#
# [torque_teno_sus_virus](torque_teno_sus_virus_pig.tsv)
